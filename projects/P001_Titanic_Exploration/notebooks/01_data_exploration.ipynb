# %% [markdown]
# # Week 1 - Titanic Dataset Exploration
#
# Author: Corina Guzman
#
# ## Objective
#
# Learn the first stage of every Machine Learning project:
#
# - Load data
# - Inspect data
# - Understand features
# - Ask good questions
# - Form hypotheses before building models

# %%
print("Welcome to the AI Architect Accelerator!")
# Out:
# Welcome to the AI Architect Accelerator!

# %% [markdown]
# # 1. Import Libraries

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# Plot settings
plt.style.use("default")
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # 2. Load Dataset

# %%
import seaborn as sns

titanic = sns.load_dataset("titanic")

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 3. Explore the Data

# %%
titanic.head()

# %% [markdown]
# # 4. Initial Observations

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # 5. Architect Questions

# %% [markdown]
# # 6. Business Interpretation

# %% [markdown]
# # 7. Architect Reflection
